# %%
from invest.Strategy import Strategy
import yfinance as yf

# %%
since = '2020-02-10'
interval = 100

# %%
tckr = yf.Ticker('^IXIC')
dF = tckr.history(start='2015-01-01', end='2022-01-01', interval='1d').Close

# %%
since = datetime.strptime(since, '%Y-%m-%d')

# %%
df = dF[since - timedelta(days=int(3/2 * interval))< dF.index]

# %%
date = datetime.strptime('2021-02-12', '%Y-%m-%d')

# %%
pos = df.index.get_loc(date)
dfmin = df.iloc[pos-interval : pos+1]

# %%
std = dfmin.std()
n = len(dfmin)

plt.plot(dfmin.index, dfmin.values)
plt.plot(dfmin.index, dfmin.values - 1.95*std/n)
plt.plot(dfmin.index, dfmin.values + 1.95*std/n)

# %%
from invest.Condition import ConditionMAX
cond = ConditionMAX(interval=30)
st = Strategy()

# %%
std
# Out:
# 915.7500709974491
