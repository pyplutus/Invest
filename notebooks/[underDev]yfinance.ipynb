# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tckrs = yf.Tickers('BTC-USD ETH-USD')

# %%
df = tckrs.history(start='2019-01-01', end='2022-01-01', interval='1d').Close
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df['BTC-USD'].rolling(365).corr(df['ETH-USD']).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['BTC-USD'].rolling(365).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['BTC-USD']=df['BTC-USD'].apply(lambda x: x/df['BTC-USD'][0])
df['ETH-USD']=df['ETH-USD'].apply(lambda x: x/df['ETH-USD'][0])

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"

fig = df.plot()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-dae1ce98d76e> in <module>
#       1 import pandas as pd
# ----> 2 pd.options.plotting.backend = "plotly"
#       3
#       4 fig = df.plot()
#       5 fig.show()
#
# ~\Dropbox\perso\GitHub\Invest\InvestVenv\lib\site-packages\pandas\_config\config.py in __setattr__(self, key, val)
#     194         # can you can't overwrite subtrees
#     195         if key in self.d and not isinstance(self.d[key], dict):
# --> 196             _set_option(prefix, val)
#     197         else:
#     198             raise OptionError("You can only set the value of existing options")
#
# ~\Dropbox\perso\GitHub\Invest\InvestVenv\lib\site-packages\pandas\_config\config.py in _set_option(*args, **kwargs)
#     128         o = _get_registered_option(key)
#     129         if o and o.validator:
# --> 130             o.validator(v)
# ...

# %%
# !pip install plotly
# Out:
# ...
#   Using cached retrying-1.3.3.tar.gz (10 kB)
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=1b09ccddcfe7907f9596f5f495bf9a215223e370e83572664e128f0d855750ec
#   Stored in directory: c:\users\mkapchenko\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['x'].rolling(3).corr(df['y']).plot()

# %%
df.corr()
# Out:
#           BTC-USD   ETH-USD
# BTC-USD  1.000000  0.771588
# ETH-USD  0.771588  1.000000

# %%
closes.corr()
# Out:
#            AAPL      ^DJI     ^IXIC
# AAPL   1.000000  0.866465  0.974911
# ^DJI   0.866465  1.000000  0.923226
# ^IXIC  0.974911  0.923226  1.000000

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()

# the ax keyword sets the axis that the data frame plots to
closes.plot(ax=ax1, y='AAPL', legend=False)
closes.plot(ax=ax2, y='^IXIC', legend=False, color='g')
ax1.set_ylabel('AAPL')
ax2.set_ylabel('NASDAQ')
plt.show()

# %%
corr = closes.corr()
corr = corr[abs(corr)>0.5]
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, mask=mask, annot=True)
# Out:
# C:\Users\mkapchenko\Dropbox\perso\GitHub\Invest\InvestVenv\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# <AxesSubplot:>

# %%
tik = yf.Ticker('FLOWCRYPTO')

# %%
tik.history('1mo')
# Out:
# - FLOWCRYPTO: No data found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
from datetime import datetime

# %%
ndate = datetime(2020,10,12)

# %%
ndate.strftime('%Y-%m-%d')
# Out:
# '2020-10-12'

# %%
import dryscrape
from bs4 import BeautifulSoup
session = dryscrape.Session()
session.visit('https://coinmarketcap.com/currencies/bitcoin/historical-data/')
response = session.body()
soup = BeautifulSoup(response)
soup.find(id="intro-text")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2c3755781136> in <module>
# ----> 1 import dryscrape
#       2 from bs4 import BeautifulSoup
#       3 session = dryscrape.Session()
#       4 session.visit('https://coinmarketcap.com/currencies/bitcoin/historical-data/')
#       5 response = session.body()
#
# ModuleNotFoundError: No module named 'dryscrape'

# %%
# !pip -V
# Out:
# pip 20.0.2 from C:\Users\mkapchenko\AppData\Local\Continuum\anaconda3\envs\neuron\lib\site-packages\pip (python 3.8)

# %%
# !pip install dryscrape
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\mkapchenko\AppData\Local\Continuum\anaconda3\envs\neuron\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mkapchenko\\AppData\\Local\\Temp\\pip-install-3d11bokt\\webkit-server\\setup.py'"'"'; __file__='"'"'C:\\Users\\mkapchenko\\AppData\\Local\\Temp\\pip-install-3d11bokt\\webkit-server\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\mkapchenko\AppData\Local\Temp\pip-wheel-6330rzru'
#        cwd: C:\Users\mkapchenko\AppData\Local\Temp\pip-install-3d11bokt\webkit-server\
#   Complete output (7 lines):
#   running bdist_wheel
#   running build
#   Project ERROR: Cannot run compiler 'cl'. Output:
# ...
#   Maybe you forgot to setup the environment?
#   error: [Errno 2] No such file or directory: 'src/webkit_server'
# ...

# %%
df = pd.DataFrame({'month': np.arange(1, 16),
                   'x': [13, 15, 16, 15, 17, 20, 22, 24, 25, 26, 23, 24, 23, 22, 20],
                   'y': [13, 15, 16, 15, 17, 26, 27, 30, 33, 26, 23, 24, 23, 26, 28]})

# %%
df['x'].rolling(5).corr(df['y']).plot(marker='o')
# Out:
# <AxesSubplot:>
